# %%
import re
from uO_scrape import get_subjects, get_courses, get_form, get_offerings
from time import sleep
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib
import json
import numpy as np

def raze_list(l):
    out = []
    for x in l:
        if type(x) == list:
            out += raze_list(x)
        else:
            out.append(x)
    return out

form = get_form()

# %%
subject_data = pd.read_csv('uOttawa_subjects.csv', index_col=False)
subject_data.head()
# Out:
#                     Subject Code                                          Link
# 0        Aboriginal Studies  eas  https://catalogue.uottawa.ca/en/courses/eas/
# 1                Accounting  cpt  https://catalogue.uottawa.ca/en/courses/cpt/
# 2            Administration  adm  https://catalogue.uottawa.ca/en/courses/adm/
# 3  Anatomy and Neurobiology  ana  https://catalogue.uottawa.ca/en/courses/ana/
# 4    Anatomy and Physiology  anp  https://catalogue.uottawa.ca/en/courses/anp/

# %%
course_data = pd.read_csv('uOttawa_courses.csv', index_col=False)
course_data.head()
# Out:
#        code           components  credits  dependencies  \
# 0  EAS 1101          ['Lecture']        3            []
# 1  EAS 1501  ['Cours magistral']        3            []
# 2  EAS 2101          ['Lecture']        3            []
# 3  EAS 2501  ['Cours magistral']        3            []
# 4  EAS 3101          ['Lecture']        3  ['EAS 2101']
#
#                                                 desc  \
# 0  Introduction to the global, cultural and relig...
# 1  Introduction à la diversité culturelle et reli...
# 2  Study of the concept and history of colonialis...
# 3  Étude conceptuelle et historique du colonialis...
# 4  Study and analysis of methodologies associated...
#
#                        prerequisites  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4  EAS 2101 or 54 university credits
#
#                                                title
# 0  Introduction to Aboriginal Societies and Cultures
# 1  Introduction aux sociétés et cultures autochtones
# 2                 Colonialism and Indigenous Peoples
# 3                Colonialisme et peuples autochtones
# 4   Research and Methodologies in Aboriginal Studies

# %%
offering_data = pd.read_csv('uOttawa_offerings_quick.csv', index_col=False)
offering_data.head()
# Out:
#        code                department                      faculty  \
# 0  ADM 1100  Administration (General)  Telfer School of Management
# 1  ADM 1101  Administration (General)  Telfer School of Management
# 2  ADM 1300  Administration (General)  Telfer School of Management
# 3  ADM 1301  Administration (General)  Telfer School of Management
# 4  ADM 1340  Administration (General)  Telfer School of Management
#
#                                          link            term  \
# 0  Course.aspx?id=000001&term=2189&session=FS  2018 Fall Term
# 1  Course.aspx?id=000002&term=2189&session=FS  2018 Fall Term
# 2  Course.aspx?id=000003&term=2189&session=FS  2018 Fall Term
# 3  Course.aspx?id=000004&term=2189&session=FS  2018 Fall Term
# 4  Course.aspx?id=000005&term=2189&session=FS  2018 Fall Term
#
#                                  title
# 0  Introduction to Business Management
# 1           Social Context of Business
# 2  Introduction to Business Management
# 3           Social Context of Business
# 4                 Financial Accounting

# %% [markdown]
# # Getting Offerings

# %%
summary = []
for course in course_data.code.tolist():
    summary.append([course, offering_data[offering_data.code.str.contains(course)]['term'].tolist()])
offerings_summary = pd.DataFrame(summary, columns = ['code', 'offered'])
offerings_summary.head(20)
# Out:
#         code             offered
# 0   EAS 1101                  []
# 1   EAS 1501  [2019 Winter Term]
# 2   EAS 2101                  []
# 3   EAS 2501                  []
# 4   EAS 3101                  []
# 5   EAS 3102                  []
# 6   EAS 3103                  []
# 7   EAS 3501                  []
# 8   EAS 3502                  []
# 9   EAS 3503                  []
# 10  EAS 4101                  []
# 11  EAS 4102                  []
# 12  EAS 4103                  []
# 13  EAS 4364                  []
# 14  EAS 4501                  []
# 15  EAS 4502                  []
# 16  EAS 4503                  []
# 17  EAS 4764                  []
# 18  CPT 5100    [2018 Fall Term]
# 19  CPT 5101                  []

# %%
offerings_summary[offerings_summary.code.str.contains('MAT 3|CSI 2|PHY 3', regex=True)].head(20)
# Out:
#           code             offered
# 2417  CSI 2101                  []
# 2418  CSI 2110    [2018 Fall Term]
# 2419  CSI 2120                  []
# 2420  CSI 2132                  []
# 2421  CSI 2372    [2018 Fall Term]
# 2422  CSI 2501                  []
# 2423  CSI 2510    [2018 Fall Term]
# 2424  CSI 2520                  []
# 2425  CSI 2532                  []
# 2426  CSI 2772    [2018 Fall Term]
# 2427  CSI 2911                  []
# 6108  MAT 3100  [2019 Winter Term]
# 6109  MAT 3101                  []
# 6110  MAT 3120                  []
# 6111  MAT 3121                  []
# 6112  MAT 3130                  []
# 6113  MAT 3141                  []
# 6114  MAT 3143  [2019 Winter Term]
# 6115  MAT 3153                  []
# 6116  MAT 3155                  []

# %% [markdown]
# # Querying Courses

# %%
course_data.dependencies = course_data.dependencies.str.replace("'", '"').apply(json.loads)

# %%
course_data['lang'] = np.where(course_data.code.str[5].apply(int) < 5, 'en', 'fr')
course_data.lang = np.where(course_data.code.str[5] == '9', 'enfr', course_data.lang)

# %%
course_data.prerequisites = np.where(course_data.prerequisites.isna(), '', course_data.prerequisites)

# %%
eng1 = course_data[(course_data.dependencies.str.len() == 0) & (course_data.code.str.startswith('ENG')) \
           & (course_data.lang.str.contains('en')) & (course_data.code.str[4].apply(int) == 1)]
eng1
# Out:
#           code                       components  credits dependencies  \
# 3757  ENG 1100  ['Discussion Group', 'Lecture']        3           []
# 3758  ENG 1112  ['Discussion Group', 'Lecture']        3           []
# 3759  ENG 1120                      ['Lecture']        3           []
# 3760  ENG 1121                      ['Lecture']        3           []
# 3761  ENG 1124                      ['Lecture']        3           []
# 3762  ENG 1131  ['Discussion Group', 'Lecture']        3           []
#
#                                                    desc prerequisites  \
# 3757  Intensive practice in academic essay writing. ...
# 3758  Practice in the writing of technical reports. ...
# 3759  Development of critical reading skills and coh...
# 3760  Development of critical reading skills and coh...
# 3761  Engagement with a specific literary topic in o...
# 3762  Development of skills in written communication...
#
#                                                 title lang
# 3757                        Workshop in Essay Writing   en
# 3758                         Technical Report Writing   en
# 3759      Literature and Composition I: Prose Fiction   en
# 3760  Literature and Composition II: Drama and Poetry   en
# 3761                         Engaging with Literature   en
# 3762                       Effective Business English   en

# %%
eng1_offers = [get_offerings(x) for x in eng1.code.tolist()]
eng1_offers = [x for x in raze_list(eng1_offers) if 'Winter' in x['term']]
eng1_offers
# Out:
# [{'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012011&term=2191&session=FS',
#   'code': 'ENG1100',
#   'title': 'Workshop in Essay Writing',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'},
#  {'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012019&term=2191&session=FS',
#   'code': 'ENG1112',
#   'title': 'Technical Report Writing',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'},
#  {'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012024&term=2191&session=FS',
#   'code': 'ENG1120',
#   'title': 'Literature and Composition I: Prose Fiction',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'},
#  {'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012025&term=2191&session=FS',
#   'code': 'ENG1121',
#   'title': 'Literature and Composition II: Drama and Poetry',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'},
#  {'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012028&term=2191&session=FS',
#   'code': 'ENG1124',
#   'title': 'Engaging with Literature',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'},
#  {'term': '2019 Winter Term',
#   'link': 'Course.aspx?id=012029&term=2191&session=FS',
#   'code': 'ENG1131',
#   'title': 'Effective Business English',
#   'faculty': 'Faculty of Arts',
#   'department': 'Department of English'}]

# %%
def is_activity(tag):
    if not(tag.name == 'tr'):
        return False
    if tag.find('td') is None:
        return False
    if not tag.has_attr('class'):
        return True
    for x in tag['class']:
        if 'first' in x or 'hidden' in x:
            return False
    return True

def get_sections(shortlink):
    r = requests.get('https://web30.uottawa.ca/v3/SITS/timetable/'+shortlink)

    sch = BeautifulSoup(r.text, 'html.parser')
    sections_table = sch.find('div', attrs={'id':'schedule'})

    sections_table = sections_table.find_all('div', attrs={'id':re.compile('[0-9]{1,}'), 'class':'schedule'})

    sections = []
    for section in sections_table:
        activities = []
        section = raze_list([list(x.find_all(is_activity)) for x in section.find_all('table')])
        for activity in section:
            tmp = dict()
            try:
                tmp['section'] = activity.find('td', attrs={'class':'Section'}).text
                tmp['activity'] = activity.find('td', attrs={'class':'Activity'}).text
                tmp['time'] = activity.find('td', attrs={'class':'Day'}).text
                tmp['location'] = activity.find('td', attrs={'class':'Place'}).text
                tmp['professor'] = activity.find('td', attrs={'class':'Professor'}).text
            except AttributeError as e:
                print(activity)
                print(activity['class'])
                raise e
            activities.append(tmp)
        sections.append(activities)
        
    return sections

# %%
eng1_times = [get_sections(x['link']) for x in eng1_offers]
eng1_times
# Out:
# [[[{'section': 'ENG1100 Y00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 19:00 - 20:20',
#     'location': 'MRT 250',
#     'professor': 'Geraldine  Arbach'},
#    {'section': 'ENG1100 Y01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Tuesday 20:30 - 21:50',
#     'location': 'MRT 251',
#     'professor': 'Geraldine  Arbach'},
#    {'section': 'ENG1100 Y02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Tuesday 20:30 - 21:50',
#     'location': 'MRT 252',
#     'professor': 'Geraldine  Arbach'}],
#   [{'section': 'ENG1100 X00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 8:30 - 9:50',
#     'location': 'VNR 1095',
#     'professor': 'Sandra  MacPherson'},
#    {'section': 'ENG1100 X01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'LMX 405',
#     'professor': 'Sandra  MacPherson'},
#    {'section': 'ENG1100 X02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'LMX 407',
#     'professor': 'Sandra  MacPherson'}],
#   [{'section': 'ENG1100 XX00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 19:00 - 20:20',
#     'location': 'CRX C307',
#     'professor': 'Paul James  Graves'},
#    {'section': 'ENG1100 XX01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Tuesday 20:30 - 21:50',
#     'location': 'LMX 407',
#     'professor': 'Paul James  Graves'},
#    {'section': 'ENG1100 XX02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Tuesday 20:30 - 21:50',
#     'location': 'LMX 405',
#     'professor': 'Paul James  Graves'}],
#   [{'section': 'ENG1100 YY00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 17:30 - 18:50',
#     'location': 'VNR 1095',
#     'professor': 'Jamie Roy  Bradley'},
#    {'section': 'ENG1100 YY01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'MRT 251',
#     'professor': 'Jamie Roy  Bradley'},
#    {'section': 'ENG1100 YY02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'MRT 252',
#     'professor': 'Jamie Roy  Bradley'}],
#   [{'section': 'ENG1100 Z00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 13:00 - 14:20',
#     'location': 'MNO E217',
#     'professor': 'Kevin  Gildea'},
#    {'section': 'ENG1100 Z01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Wednesday 14:30 - 15:50',
#     'location': 'MNO C211',
#     'professor': 'Kevin  Gildea'},
#    {'section': 'ENG1100 Z02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Wednesday 14:30 - 15:50',
#     'location': 'SMD 422',
#     'professor': 'Kevin  Gildea'}],
#   [{'section': 'ENG1100 ZZ00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 9:50',
#     'location': 'VNR 5070',
#     'professor': 'Aaron Samuel  Kaiserman'},
#    {'section': 'ENG1100 ZZ01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 10:00 - 11:20',
#     'location': 'SMD 224',
#     'professor': 'Aaron Samuel  Kaiserman'},
#    {'section': 'ENG1100 ZZ02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 10:00 - 11:20',
#     'location': 'HGN 302',
#     'professor': 'Aaron Samuel  Kaiserman'}]],
#  [[{'section': 'ENG1112 H00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 17:30 - 18:50',
#     'location': 'DMS 1140',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 H01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'HGN 305',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 H02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'TBT 317',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 H03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'TBT 315',
#     'professor': 'Gefen  Bar-On Santor'}],
#   [{'section': 'ENG1112 I00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 17:30 - 18:50',
#     'location': 'DMS 1140',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 I01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'MNT 103',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 I02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'TBT 327',
#     'professor': 'Gefen  Bar-On Santor'},
#    {'section': 'ENG1112 I03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'TBT 319',
#     'professor': 'Gefen  Bar-On Santor'}],
#   [{'section': 'ENG1112 J00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 19:00 - 20:20',
#     'location': 'MRT 212',
#     'professor': 'Geraldine  Arbach'},
#    {'section': 'ENG1112 J01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 20:30 - 21:50',
#     'location': 'LMX 407',
#     'professor': 'Geraldine  Arbach'},
#    {'section': 'ENG1112 J02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 20:30 - 21:50',
#     'location': 'LMX 405',
#     'professor': 'Geraldine  Arbach'},
#    {'section': 'ENG1112 J03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 20:30 - 21:50',
#     'location': 'SMD 427',
#     'professor': 'Geraldine  Arbach'}]],
#  [[{'section': 'ENG1120 B00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 11:30 - 12:50',
#     'location': 'MNT 207',
#     'professor': 'Kelly M.  St-Jacques'},
#    {'section': 'ENG1120 B00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 13:00 - 14:20',
#     'location': 'VNR 3035',
#     'professor': 'Kelly M.  St-Jacques'}],
#   [{'section': 'ENG1120 I00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 17:30 - 20:20',
#     'location': 'VNR 3035',
#     'professor': 'Jennifer  Blair,Sandra  MacPherson'}],
#   [{'section': 'ENG1120 J00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 11:30 - 12:50',
#     'location': 'VNR 2095',
#     'professor': 'Not available at this time.'},
#    {'section': 'ENG1120 J00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 13:00 - 14:20',
#     'location': 'VNR 2095',
#     'professor': 'Natalie  Taylor'}],
#   [{'section': 'ENG1120 K00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 13:00 - 14:20',
#     'location': 'VNR 5070',
#     'professor': 'Breid  McIlkenny'},
#    {'section': 'ENG1120 K00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 11:30 - 12:50',
#     'location': 'VNR 3035',
#     'professor': 'Breid  McIlkenny'}],
#   [{'section': 'ENG1120 L00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 14:30 - 15:50',
#     'location': 'VNR 3035',
#     'professor': 'Not available at this time.'},
#    {'section': 'ENG1120 L00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 16:00 - 17:20',
#     'location': 'VNR 1095',
#     'professor': 'Aaron Samuel  Kaiserman'}],
#   [{'section': 'ENG1120 M00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 13:00 - 14:20',
#     'location': 'VNR 3035',
#     'professor': 'Elaine Sarah  Bailey'},
#    {'section': 'ENG1120 M00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 11:30 - 12:50',
#     'location': 'VNR 2095',
#     'professor': 'Elaine Sarah  Bailey'}],
#   [{'section': 'ENG1120 N00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 11:30 - 12:50',
#     'location': 'CRX C307',
#     'professor': 'Miles  Tittle'},
#    {'section': 'ENG1120 N00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 13:00 - 14:20',
#     'location': 'CRX C307',
#     'professor': 'Miles  Tittle'}],
#   [{'section': 'ENG1120 O00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 17:30 - 18:50',
#     'location': 'VNR 5070',
#     'professor': 'Karenza  Sutton'},
#    {'section': 'ENG1120 O00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 17:30 - 18:50',
#     'location': 'VNR 5070',
#     'professor': 'Karenza  Sutton'}],
#   [{'section': 'ENG1120 P00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 9:50',
#     'location': 'VNR 3035',
#     'professor': 'Natalie  Taylor'},
#    {'section': 'ENG1120 P00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 10:00 - 11:20',
#     'location': 'MRT 205',
#     'professor': 'Natalie  Taylor'}],
#   [{'section': 'ENG1120 PJ00(January 07 - April 05)CA Pembroke Algonquin College',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 11:20',
#     'location': 'DEP DEPT',
#     'professor': 'Alan George H.  West'}],
#   [{'section': 'ENG1120 Q00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'VNR 5070',
#     'professor': 'Jason  Liboiron'},
#    {'section': 'ENG1120 Q00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 8:30 - 9:50',
#     'location': 'LMX 221',
#     'professor': 'Jason  Liboiron'}],
#   [{'section': 'ENG1120 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 19:00 - 21:50',
#     'location': 'VNR 3035',
#     'professor': 'Timothy  Wilson'}],
#   [{'section': 'ENG1120 R00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 19:00 - 21:50',
#     'location': 'CRX C307',
#     'professor': 'Lorrie Beryle  Graham'}],
#   [{'section': 'ENG1120 S00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 8:30 - 11:20',
#     'location': 'TBT 070',
#     'professor': 'Alan George H.  West'}],
#   [{'section': 'ENG1120 T00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 11:20',
#     'location': 'LPR 155',
#     'professor': 'Alan George H.  West'}],
#   [{'section': 'ENG1120 U00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'VNR 3035',
#     'professor': 'Erin M  Kean'},
#    {'section': 'ENG1120 U00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 17:30 - 18:50',
#     'location': 'VNR 3035',
#     'professor': 'Erin M  Kean'}],
#   [{'section': 'ENG1120 V00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 14:30 - 15:50',
#     'location': 'VNR 1095',
#     'professor': 'Sandra  MacPherson'},
#    {'section': 'ENG1120 V00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 16:00 - 17:20',
#     'location': 'VNR 1095',
#     'professor': 'Sandra  MacPherson'}],
#   [{'section': 'ENG1120 W00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 8:30 - 9:50',
#     'location': 'VNR 5070',
#     'professor': 'Miles  Tittle'},
#    {'section': 'ENG1120 W00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 10:00 - 11:20',
#     'location': 'HNN 013',
#     'professor': 'Miles  Tittle'}],
#   [{'section': 'ENG1120 CJ00(January 07 - April 05)CA Cornwall',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 11:20',
#     'location': 'DEP DEPT',
#     'professor': 'Alan George H.  West'}],
#   [{'section': 'ENG1120 D00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 8:30 - 11:20',
#     'location': 'VNR 5070',
#     'professor': 'Christopher  Jenkins'}],
#   [{'section': 'ENG1120 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 10:00 - 11:20',
#     'location': 'VNR 5070',
#     'professor': 'Breid  McIlkenny'},
#    {'section': 'ENG1120 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 8:30 - 9:50',
#     'location': 'MNO E217',
#     'professor': 'Breid  McIlkenny'}],
#   [{'section': 'ENG1120 F00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 10:00 - 11:20',
#     'location': 'VNR 3035',
#     'professor': 'Elaine Sarah  Bailey'},
#    {'section': 'ENG1120 F00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 8:30 - 9:50',
#     'location': 'VNR 5070',
#     'professor': 'Elaine Sarah  Bailey'}],
#   [{'section': 'ENG1120 G00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'VNR 3035',
#     'professor': 'Jennifer Lynne  Macquarrie'},
#    {'section': 'ENG1120 G00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 8:30 - 9:50',
#     'location': 'CRX C308',
#     'professor': 'Jennifer Lynne  Macquarrie'}],
#   [{'section': 'ENG1120 H00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'VNR 3035',
#     'professor': 'Breid  McIlkenny'},
#    {'section': 'ENG1120 H00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 14:30 - 15:50',
#     'location': 'MNT 201',
#     'professor': 'Breid  McIlkenny'}],
#   [{'section': 'ENG1120 HJ00(January 07 - April 05)CA Hawkesbury',
#     'activity': 'LEC',
#     'time': 'Friday 8:30 - 11:20',
#     'location': 'DEP DEPT',
#     'professor': 'Alan George H.  West'}]],
#  [[{'section': 'ENG1121 B00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 14:30 - 15:50',
#     'location': 'VNR 5070',
#     'professor': 'Natalia  Vesselova'},
#    {'section': 'ENG1121 B00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 16:00 - 17:20',
#     'location': 'DMS 1110',
#     'professor': 'Natalia  Vesselova'}],
#   [{'section': 'ENG1121 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 8:30 - 9:50',
#     'location': 'VNR 5070',
#     'professor': 'Nicholas  Von Maltzahn'},
#    {'section': 'ENG1121 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 10:00 - 11:20',
#     'location': 'VNR 3035',
#     'professor': 'Nicholas  Von Maltzahn'}],
#   [{'section': 'ENG1121 D00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 8:30 - 9:50',
#     'location': 'VNR 3035',
#     'professor': 'Rosemary Ellen  Daniels'},
#    {'section': 'ENG1121 D00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 10:00 - 11:20',
#     'location': 'CRX C307',
#     'professor': 'Rosemary Ellen  Daniels'}],
#   [{'section': 'ENG1121 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 11:30 - 12:50',
#     'location': 'VNR 5070',
#     'professor': 'Rosemary Ellen  Daniels'},
#    {'section': 'ENG1121 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 13:00 - 14:20',
#     'location': 'MNT 207',
#     'professor': 'Rosemary Ellen  Daniels'}],
#   [{'section': 'ENG1121 F00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 11:30 - 12:50',
#     'location': 'FTX 135',
#     'professor': 'Natalia  Vesselova'},
#    {'section': 'ENG1121 F00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 13:00 - 14:20',
#     'location': 'TBT 325',
#     'professor': 'Natalia  Vesselova'}],
#   [{'section': 'ENG1121 G00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 13:00 - 14:20',
#     'location': 'CRX C307',
#     'professor': 'Not available at this time.'},
#    {'section': 'ENG1121 G00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 11:30 - 12:50',
#     'location': 'CRX C307',
#     'professor': 'Paulo Eduardo  Castilho Ribeiro Santos'}],
#   [{'section': 'ENG1121 H00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 14:30 - 17:20',
#     'location': 'VNR 2095',
#     'professor': 'Paul James  Graves'}]],
#  [[{'section': 'ENG1124 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Thursday 11:30 - 12:50',
#     'location': 'UCU 205',
#     'professor': 'Victoria E Burke'},
#    {'section': 'ENG1124 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 13:00 - 14:20',
#     'location': 'UCU 205',
#     'professor': 'Victoria E Burke'}],
#   [{'section': 'ENG1124 D00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 14:30 - 17:20',
#     'location': 'WLD 110',
#     'professor': 'Ian  Dennis'}],
#   [{'section': 'ENG1124 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Wednesday 14:30 - 15:50',
#     'location': 'VNR 2075',
#     'professor': 'Geoff  Rector'},
#    {'section': 'ENG1124 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 16:00 - 17:20',
#     'location': 'TBT 0019',
#     'professor': 'Geoff  Rector'}]],
#  [[{'section': 'ENG1131 B00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Friday 17:30 - 18:50',
#     'location': 'DMS 1150',
#     'professor': 'Trevor  Tucker'},
#    {'section': 'ENG1131 B01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'LMX 407',
#     'professor': 'Trevor  Tucker'},
#    {'section': 'ENG1131 B02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'LMX 405',
#     'professor': 'Trevor  Tucker'},
#    {'section': 'ENG1131 B03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 19:00 - 20:20',
#     'location': 'SMD 427',
#     'professor': 'Trevor  Tucker'}],
#   [{'section': 'ENG1131 C00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 8:30 - 9:50',
#     'location': 'MRT 212',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 C01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'SMD 221',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 C02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'WLD 108',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 C03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 10:00 - 11:20',
#     'location': 'LMX 342',
#     'professor': 'Elena  Ilina'}],
#   [{'section': 'ENG1131 D00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Monday 17:30 - 18:50',
#     'location': 'MRT 212',
#     'professor': 'David  Sacks'},
#    {'section': 'ENG1131 D01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Wednesday 17:30 - 18:50',
#     'location': 'TBT 0021',
#     'professor': 'David  Sacks'},
#    {'section': 'ENG1131 D02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Wednesday 17:30 - 18:50',
#     'location': 'TBT 317',
#     'professor': 'David  Sacks'},
#    {'section': 'ENG1131 D03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Wednesday 17:30 - 18:50',
#     'location': 'TBT 315',
#     'professor': 'David  Sacks'}],
#   [{'section': 'ENG1131 E00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 14:30 - 15:50',
#     'location': 'DMS 1140',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 E01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'MRT 015',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 E02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'TBT 0021',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 E03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'TBT 317',
#     'professor': 'Jordan Paul Rendell Smith'}],
#   [{'section': 'ENG1131 F00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 17:30 - 18:50',
#     'location': 'MRT 212',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 F01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'CBY B202',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 F02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'MNT 204',
#     'professor': 'Jordan Paul Rendell Smith'},
#    {'section': 'ENG1131 F03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Thursday 17:30 - 18:50',
#     'location': 'MNT 103',
#     'professor': 'Jordan Paul Rendell Smith'}],
#   [{'section': 'ENG1131 G00(January 07 - April 05)',
#     'activity': 'LEC',
#     'time': 'Tuesday 14:30 - 15:50',
#     'location': 'MRT 212',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 G01(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'CBY B202',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 G02(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'MNT 204',
#     'professor': 'Elena  Ilina'},
#    {'section': 'ENG1131 G03(January 07 - April 05)',
#     'activity': 'DGD',
#     'time': 'Friday 16:00 - 17:20',
#     'location': 'TBT 327',
#     'professor': 'Elena  Ilina'}]]]

# %% [markdown]
# # Query Future Courses

# %%
mpc = course_data[course_data.code.str.contains('MAT [34]|CSI [34]|PHY [34]', regex=True)]

# %%
mpc_offers = [get_offerings(x) for x in mpc.code.tolist()]
mpc_offers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1fbcb9f9e91c> in <module>()
# ----> 1 mpc_offers = [get_offerings(x) for x in mpc.code.tolist()]
#       2 mpc_offers
#
# <ipython-input-8-1fbcb9f9e91c> in <listcomp>(.0)
# ----> 1 mpc_offers = [get_offerings(x) for x in mpc.code.tolist()]
#       2 mpc_offers
#
# ~\ajn_doc\Projects\Programming\Python\uOcourses\uO_scrape.py in get_offerings(subject, code, form, timetable_url, session)
#     226         form['ctl00$MainContentPlaceHolder$Basic_CatalogNumberText'] = code
#     227
# --> 228         courses_sch = get_courses_sch(timetable_url, form, session)
#     229         courses_offers = []
#     230         #parsing out the information from the HTML bs4 tag returned by get_courses_sch
#
# ~\ajn_doc\Projects\Programming\Python\uOcourses\uO_scrape.py in get_courses_sch(url, form, session)
#     257         courses = BeautifulSoup(r.text, 'html.parser')
#     258
# --> 259         result = courses.find('div', attrs={'class':'result'}).text.strip().replace('\r', '').replace('\n', '').replace(' ', '').lower()
#     260         if '0coursescorrespondtoyoursearchcriteria' in result:
#     261                 return []
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
json.loads(course_data[course_data.code.str.contains('CSI 3105')].to_json(orient='records'))

# %%
def recordify(df):
    return json.loads(df.to_json(orient='records'))

# %%
recordify(course_data[course_data.code.str.contains("MAT 33(48|61)", regex=True) & course_data.lang.str.contains('en')])
