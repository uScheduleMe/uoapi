# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import json
from uO_scrape import scrape_subjects, get_course_tables, get_courses, extract_credits, extract_codes

# %% [markdown]
# # Subjects

# %%
subjects = scrape_subjects()
subjects.head()

# %%
if len(subjects) != len(set(subjects.Code)):
    print("WARNING! NON-UNIQUE SUBJECT CODES HAVE BEEN DETECTED.")

# %%
subjects.to_csv("uOttawa_subjects.csv", index=False)

# %% [markdown]
# # Course Description

# %%
links = subjects.Link.tolist()

course_tables = get_course_tables(links)

# %%
course_tables['mat']
# Out:
#          code                                              title  credits  \
# 0    MAT 1300                             Mathematical Methods I        3
# 1    MAT 1302                            Mathematical Methods II        3
# 2    MAT 1303                           Mathematical Methods III        3
# 3    MAT 1308                           Introduction to Calculus        3
# 4    MAT 1318                                          Functions        3
# 5    MAT 1320                                         Calculus I        3
# 6    MAT 1322                                        Calculus II        3
# 7    MAT 1325        Calculus II and an Introduction to Analysis        3
# 8    MAT 1330                   Calculus for the Life Sciences I        3
# 9    MAT 1332                  Calculus for the Life Sciences II        3
# 10   MAT 1339               Introduction to Calculus and Vectors        3
# 11   MAT 1341                     Introduction to Linear Algebra        3
# 12   MAT 1348                 Discrete Mathematics for Computing        3
# 13   MAT 1362                  Mathematical Reasoning and Proofs        3
# 14   MAT 1371                             Descriptive Statistics        3
# 15   MAT 1372  Elements of Probability and Statistical Inference        3
# 16   MAT 1373                          Data Analysis By Computer        3
# 17   MAT 1374         Probability and Games of Chance: Poker 101        3
# 18   MAT 1395                          The Beauty of Mathematics        3
# 19   MAT 1700                           Méthodes mathématiques I        3
# 20   MAT 1702                          Méthodes mathématiques II        3
# 21   MAT 1703                         Méthodes mathématiques III        3
# 22   MAT 1708    Introduction au calcul différentiel et intégral        3
# 23   MAT 1718                                          Fonctions        3
# 24   MAT 1720                  Calcul différentiel et intégral I        3
# 25   MAT 1722                 Calcul différentiel et intégral II        3
# 26   MAT 1725  Calcul différentiel et intégral II et introduc...        3
# 27   MAT 1730  Calcul différentiel et intégral pour les scien...        3
# 28   MAT 1732  Calcul différentiel et intégral pour les scien...        3
# 29   MAT 1739                 Introduction au calcul et vecteurs        3
# ..        ...                                                ...      ...
# 300  MAT 5580  Analyse numérique I pour les équations différe...        3
# 301  MAT 5591                              Inférence statistique        3
# 302  MAT 5593                                  Modèles linéaires        3
# 303  MAT 5595                                 Plan d'expériences        3
# 304  MAT 5596                                Analyse multivariée        3
# 305  MAT 5597                          Optimisation stochastique        3
# 306  MAT 5598                              Modèles stochastiques        3
# 307  MAT 5709                 Analyse harmonique sur les groupes        3
# 308  MAT 5712                      Topologie : Chapitres choisis        3
# 309  MAT 5713               Topics in Probability and Statistics        3
# 310  MAT 5714                  Théories problèmes et statistique        3
# 311  MAT 5715                         Planification des sondages        3
# 312  MAT 5726                        Analyse : Chapitres choisis        3
# 313  MAT 5727  Algèbre - chapitres choisis : Introduction à l...        3
# 314  MAT 5728                        Analyse : Chapitres choisis        3
# 315  MAT 5729                        Analyse : Chapitres choisis        3
# 316  MAT 5730                        Analyse : Chapitres choisis        3
# 317  MAT 5731                        Analyse : Chapitres choisis        3
# 318  MAT 5761           Logique mathématique : Chapitres choisis        3
# 319  MAT 5775                      Statistiques en mathématiques        3
# 320  MAT 5990                          Séminaire / Seminar ( / )        3
# 321  MAT 5990             S M.Sc. Séminaire / Seminar M.A. ( / )        3
# 322  MAT 5990                        T Séminaire / Seminar ( / )        3
# 323  MAT 5991           Travaux dirigés / Directed Studies ( / )        3
# 324  MAT 5992                     Seminar in Biostatistics ( / )        3
# 325  MAT 5996     Stage de recherche / Research Internship ( / )        3
# 326  MAT 6990                          Séminaire / Seminar ( / )        3
# 327  MAT 6991           Travaux dirigés / Directed Studies ( / )        3
# 328  MAT 6997  Projet en mathématiques et statistique / Proje...        6
# 329  MAT 9998         Examen général / Comprehensive Examination        0
#
#                                                   desc  \
# 0    Review of elementary functions.  Limits.  Geom...
# 1    Solution of systems of linear equations. Matri...
# 2    Sequences, series, power series, Taylor series...
# 3    Review of elementary functions. Introduction t...
# 4    Polynomial and rational functions: factoring, ...
# 5    Intuitive definition of limits; continuity, st...
# 6    Improper integrals.  Applications of the integ...
# 7    A second course in calculus emphasizing geomet...
# 8    Derivatives: product and quotient rules, chain...
# 9    Integrals: numerical integration; improper int...
# 10   Instantaneous rate of change as a limit, deriv...
# 11   Review of complex numbers. The fundamental the...
# 12   Introduction to discrete structures as a found...
# 13   Elements of logic, set theory, functions, equi...
# 14   Topics from descriptive statistics: histograms...
# 15   Probability distributions. Law of large number...
# 16   Introduction to a statistical package on a  co...
# 17   An introduction to elementary probability theo...
# 18   Selected topics from modern and ancient mathem...
# 19   Révision des fonctions élémentaires.  Limites....
# 20   Solutions de systèmes d'équations linéaires. A...
# 21   Suites, séries, séries entières, séries de Tay...
# 22   Révision des fonctions élémentaires, introduct...
# 23   Fonctions polynômiales et rationnelles: factor...
# 24   Définition intuitive de la limite; la continui...
# 25   Intégrales impropres.  Applications de l'intég...
# 26   Ce deuxième cours de calcul différentiel et in...
# 27   Dérivées: règles du produit et du quotient, dé...
# 28   Intégrales: intégration numérique, intégrales ...
# 29   Taux de variation instantané comme limite, dér...
# ..                                                 ...
# 300  Arithmétique des nombres à virgule flottante; ...
# 301  Ce cours est équivalent à STAT 5501 à la Carle...
# 302  Théorie des modèles linéaires des rangs non-ex...
# 303  Aperçu de la théorie du modèle linéaire; ortho...
# 304  Cours visant à donner à l'étudiant la possibil...
# 305  Ce cours est équivalent à STAT 5601 à la Carle...
# 306  Ce cours est équivalent à MATH 5701 à la Carle...
# 307  Ce cours est équivalent à MATH 6002 à la Carle...
# 308  Ce cours est équivalent à MATH 6201 à la Carle...
# 309  Ce cours est équivalent à MATH 6507 à la Carle...
# 310  Ce cours est équivalent à MATH 6508 à la Carle...
# 311                            Volet : Cours magistral
# 312  Ce cours est équivalent à MATH 6008 à la Carle...
# 313  Ce cours est équivalent à MATH 6101 à la Carle...
# 314  Ce cours est équivalent à MATH 6008 à la Carle...
# 315  Ce cours est équivalent à MATH 6009 à la Carle...
# 316  Ce cours est équivalent à MATH 6102 à la Carle...
# 317  Ce cours est équivalent à MATH 6103 à la Carle...
# 318  Ce cours est équivalent à MATH 6806 à la Carle...
# 319  L'inférence statistique; distributions des sta...
# 320  Ce cours est équivalent à MATH 5900 à la Carle...
# 321  Volet / Course Component: Cours magistral / Le...
# 322  Volet / Course Component: Cours magistral / Le...
# 323  Ce cours est équivalent à MATH 5901 à la Carle...
# 324  Students work in teams on the analysis of expe...
# 325  Cours visant à donner à l'étudiant la possibil...
# 326  Ce cours est équivalent à MATH 6900 à la Carle...
# 327  Ce cours est équivalent à MATH 6901 à la Carle...
# 328  Projet en mathématiques et statistique dirigé ...
# 329     Volet / Course Component: Recherche / Research
#
#                                   components  \
# 0                [Discussion Group, Lecture]
# 1                [Discussion Group, Lecture]
# 2                                  [Lecture]
# 3                [Discussion Group, Lecture]
# 4                                  [Lecture]
# 5                [Discussion Group, Lecture]
# 6                [Discussion Group, Lecture]
# 7                [Discussion Group, Lecture]
# 8                [Discussion Group, Lecture]
# 9                [Discussion Group, Lecture]
# 10               [Discussion Group, Lecture]
# 11               [Discussion Group, Lecture]
# 12               [Discussion Group, Lecture]
# 13               [Discussion Group, Lecture]
# 14               [Discussion Group, Lecture]
# 15                     [Laboratory, Lecture]
# 16                                 [Lecture]
# 17                                 [Lecture]
# 18                                 [Lecture]
# 19   [Groupe de discussion, Cours magistral]
# 20   [Groupe de discussion, Cours magistral]
# 21                         [Cours magistral]
# 22   [Groupe de discussion, Cours magistral]
# 23                         [Cours magistral]
# 24   [Groupe de discussion, Cours magistral]
# 25   [Groupe de discussion, Cours magistral]
# 26   [Groupe de discussion, Cours magistral]
# 27   [Groupe de discussion, Cours magistral]
# 28   [Groupe de discussion, Cours magistral]
# 29   [Groupe de discussion, Cours magistral]
# ..                                       ...
# 300                        [Cours magistral]
# 301                        [Cours magistral]
# 302                        [Cours magistral]
# 303                        [Cours magistral]
# 304                        [Cours magistral]
# 305                        [Cours magistral]
# 306                        [Cours magistral]
# 307                        [Cours magistral]
# 308                        [Cours magistral]
# 309                        [Cours magistral]
# 310                        [Cours magistral]
# 311                        [Cours magistral]
# 312                        [Cours magistral]
# 313                        [Cours magistral]
# 314                        [Cours magistral]
# 315                        [Cours magistral]
# 316                        [Cours magistral]
# 317                        [Cours magistral]
# 318                        [Cours magistral]
# 319                        [Cours magistral]
# 320                                [Lecture]
# 321                                [Lecture]
# 322                                [Lecture]
# 323                               [Research]
# 324                                [Lecture]
# 325                                [Lecture]
# 326                                [Lecture]
# 327                               [Research]
# 328                               [Research]
# 329                               [Research]
#
#                                          prerequisites  \
# 0    One of Calculus and Vectors (MCV4U) or MAT 133...
# 1    One of Ontario 4U Mathematics of Data Manageme...
# 2    MAT 1300. MAT 1302 is corequisite to MAT 1303....
# 3    One of Advanced Functions (MHF4U) or MAT 1318 ...
# 4    Ontario grade 11 Functions (MCR3U) or the equi...
# 5    One of MAT1339, Ontario 4U Calculus and Vector...
# 6    MAT 1320. The courses MAT 1322, MAT 1303, MAT ...
# 7    MAT 1320. The courses MAT 1325, MAT 1303, MAT ...
# 8    One of MAT1339, Ontario 4U Calculus and Vector...
# 9    MAT 1330. The courses MAT 1332, MAT 1303, MAT ...
# 10   Ontario 4U Functions (MHF4U) or MAT 1318 or eq...
# 11   MAT1339 or Ontario 4U Calculus and Vectors (MC...
# 12   MAT 1318 or Ontario 4U Advanced Functions (MHF...
# 13   MAT 1339 or Ontario 4U Calculus and Vectors (M...
# 14
# 15   MAT 1371. The courses MAT 1372, MAT 2371, MAT ...
# 16
# 17
# 18   This course cannot count as a science elective...
# 19   Calcul et vecteurs (MCV4U) ou MAT 1739. Les co...
# 20   Mathématiques 4U de l'Ontario ou Mathématiques...
# 21   MAT  1700. MAT 1702 est concomitant à MAT 1703...
# 22   Un des cours suivants : Fonctions avancées (MH...
# 23   Les Mathématiques de la 11e année de l'Ontario...
# 24   MAT1739 ou Mathématiques 4U de l'Ontario Calcu...
# 25   MAT 1720. Les cours MAT 1722, MAT 1703, MAT 17...
# 26   MAT 1720. Les cours MAT 1725, MAT 1703, MAT 17...
# 27   MAT1739 ou Mathématiques 4U de l'Ontario (MCV4...
# 28   MAT 1730. Les cours MAT 1732, MAT 1703, MAT 17...
# 29   Mathématiques 4U de l'Ontario Fonctions avancé...
# ..                                                 ...
# 300
# 301                                           MAT 5190
# 302                          Prerequisite for MAT 5593
# 303
# 304                           Permission de l'Institut
# 305                              STAT 3506 or MAT 4371
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
#
#                                       dependencies
# 0                                       {MAT 1339}
# 1                               {MAT1318, MAT1339}
# 2                             {MAT 1302, MAT 1300}
# 3                                       {MAT 1318}
# 4                                               {}
# 5                                        {MAT1339}
# 6                                       {MAT 1320}
# 7                                       {MAT 1320}
# 8                                        {MAT1339}
# 9                                       {MAT 1330}
# 10                                      {MAT 1318}
# 11                                       {MAT1339}
# 12                                      {MAT 1318}
# 13                                      {MAT 1339}
# 14                                              {}
# 15                                      {MAT 1371}
# 16                                              {}
# 17                                              {}
# 18                                              {}
# 19        {MAT 1708, MAT 1739, MAT 1730, MAT 1720}
# 20                  {MAT 1718, MAT 1739, MAT 1741}
# 21        {MAT 1725, MAT 1732, MAT 1722, MAT 1702}
# 22        {MAT 1720, MAT 1700, MAT 1718, MAT 1730}
# 23                                              {}
# 24   {MAT1720, MAT1730, MAT1700, MAT1739, MAT1708}
# 25        {MAT 1720, MAT 1703, MAT 1725, MAT 1732}
# 26        {MAT 1720, MAT 1703, MAT 1722, MAT 1732}
# 27   {MAT1720, MAT1730, MAT1700, MAT1739, MAT1708}
# 28        {MAT 1725, MAT 1730, MAT 1722, MAT 1703}
# 29                                      {MAT 1718}
# ..                                             ...
# 300                                             {}
# 301                                     {MAT 5190}
# 302                                             {}
# 303                                             {}
# 304                                             {}
# 305                           {MAT 4371, TAT 3506}
# 306                                             {}
# 307                                             {}
# 308                                             {}
# 309                                             {}
# 310                                             {}
# 311                                             {}
# 312                                             {}
# 313                                             {}
# 314                                             {}
# 315                                             {}
# 316                                             {}
# 317                                             {}
# 318                                             {}
# 319                                             {}
# 320                                             {}
# 321                                             {}
# 322                                             {}
# 323                                             {}
# 324                                             {}
# 325                                             {}
# 326                                             {}
# 327                                             {}
# 328                                             {}
# 329                                             {}
#
# [330 rows x 7 columns]

# %%
json_courses = dict()
for key in course_tables:
    json_courses[key] = course_tables[key].to_json(orient='records')

with open("uOttawa_courses.json", 'w') as f:
    json.dump(json_courses, f, indent='\t')

# %%
all_courses = pd.concat([course_tables[key] for key in course_tables])
print(len(all_courses))
all_courses.to_csv('uOttawa_courses.csv', index=False)
all_courses.head()
# Out:
# 10091
#        code         components  credits dependencies  \
# 0  EAS 1101          [Lecture]        3           []
# 1  EAS 1501  [Cours magistral]        3           []
# 2  EAS 2101          [Lecture]        3           []
# 3  EAS 2501  [Cours magistral]        3           []
# 4  EAS 3101          [Lecture]        3   [EAS 2101]
#
#                                                 desc  \
# 0  Introduction to the global, cultural and relig...
# 1  Introduction à la diversité culturelle et reli...
# 2  Study of the concept and history of colonialis...
# 3  Étude conceptuelle et historique du colonialis...
# 4  Study and analysis of methodologies associated...
#
#                        prerequisites  \
# 0
# 1
# 2
# 3
# 4  EAS 2101 or 54 university credits
#
#                                                title
# 0  Introduction to Aboriginal Societies and Cultures
# 1  Introduction aux sociétés et cultures autochtones
# 2                 Colonialism and Indigenous Peoples
# 3                Colonialisme et peuples autochtones
# 4   Research and Methodologies in Aboriginal Studies
